# %% [markdown]
# # Financial Times

# %%
import pandas as pd

# List of CSV files to concatenate
csv_files = [
    "ft_oil_articles.csv",
    "ft_oil_articles_part_2.csv",
    "ft_oil_articles_part_3.csv",
]

# List to hold DataFrames
dataframes = []

# Read each CSV file into a DataFrame and append to the list
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Concatenate all DataFrames
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df
# Out:
#                                                Headline  \
# 0     Vitol plans metals move to hedge against decli...
# 1     Europe’s winter gas supplies at risk from mark...
# 2                     Big Oil’s dirty legacy in Nigeria
# 3     Lukoil considered sale of Bulgarian refinery t...
# 4     Trudeau government under fire from all sides o...
# ...                                                 ...
# 3765              UK gas prices surge on Asia LNG rally
# 3766  Third of low-carbon funds invest in oil and ga...
# 3767  Hurricane Energy warns shareholders could be l...
# 3768                Trump’s grandstanding in the Arctic
# 3769  Cairn to pay $250m special dividend after sale...
#
#                              Date
# 0      Thursday, 7 November, 2024
# 1      Thursday, 7 November, 2024
# 2     Wednesday, 6 November, 2024
# 3       Tuesday, 5 November, 2024
# 4       Tuesday, 5 November, 2024
# ...                           ...
# 3765    Sunday, 20 December, 2020
# 3766    Sunday, 20 December, 2020
# 3767    Friday, 18 December, 2020
# 3768  Thursday, 17 December, 2020
# 3769  Thursday, 17 December, 2020
#
# [3770 rows x 2 columns]

# %%
combined_df = combined_df [(combined_df ['Date'] != "No date") & (combined_df ['Headline'] != "No headline")]   

# Sort the DataFrame by Date to ensure chronological order
combined_df['Date'] = pd.to_datetime(combined_df['Date'], format='%A, %d %B, %Y')  # Adjust the format as necessary


# Combine headlines for duplicate dates
df_grouped = combined_df.groupby('Date', as_index=False).agg({'Headline': '. '.join})
# Out:
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\1050227104.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['Date'] = pd.to_datetime(combined_df['Date'], format='%A, %d %B, %Y')  # Adjust the format as necessary

# %%
df_grouped
# Out:
#            Date                                           Headline
# 0    2020-12-17  Trump’s grandstanding in the Arctic. Cairn to ...
# 1    2020-12-18  Hurricane Energy warns shareholders could be l...
# 2    2020-12-20  UK gas prices surge on Asia LNG rally. Third o...
# 3    2020-12-21  Shell to take further writedown after bruising...
# 4    2020-12-22  UK Oil & Gas wins dispute with climate activis...
# ...         ...                                                ...
# 1144 2024-11-03  Opec+ members delay planned rise in oil produc...
# 1145 2024-11-04  AI’s huge power needs give oil majors incentiv...
# 1146 2024-11-05  Lukoil considered sale of Bulgarian refinery t...
# 1147 2024-11-06                  Big Oil’s dirty legacy in Nigeria
# 1148 2024-11-07  Vitol plans metals move to hedge against decli...
#
# [1149 rows x 2 columns]

# %%
start_date = pd.Timestamp('2021-01-04')
end_date = pd.Timestamp('2024-10-10')

final_df = df_grouped[(df_grouped['Date'] >= start_date) & (df_grouped['Date'] <= end_date)]
final_df.head(10)
# Out:
#          Date                                           Headline
# 12 2021-01-04  Saudi Arabia warns oil producers over fragile ...
# 13 2021-01-05  Saudis pledge to cut oil output despite Russia...
# 14 2021-01-06  Oil auction in Arctic wildlife refuge draws sc...
# 15 2021-01-07  A Democratic Senate provides a surge for Biden...
# 16 2021-01-08  UK’s FTSE 100 kicks off 2021 with 6% rally lif...
# 17 2021-01-10      Gazprom to restart Nord Stream 2 construction
# 18 2021-01-11  Wind power overtakes coal in Texas electricity...
# 19 2021-01-12  Climate activists choke Appalachian pipeline e...
# 20 2021-01-13  Hydrogen project aims to drive UK transition t...
# 21 2021-01-14  How Mexico’s Pemex went from cash cow to finan...

# %%
full_date_range = pd.date_range(start=start_date, end=end_date)

# Create a DataFrame with the full date range
df_full = pd.DataFrame({"Date": full_date_range})

# Merge with the grouped DataFrame
df_full = df_full.merge(final_df, on="Date", how="left")

# Forward fill missing headlines
df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
df_full.head(10)
# Out:
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\3994148628.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
#         Date                                           Headline
# 0 2021-01-04  Saudi Arabia warns oil producers over fragile ...
# 1 2021-01-05  Saudis pledge to cut oil output despite Russia...
# 2 2021-01-06  Oil auction in Arctic wildlife refuge draws sc...
# 3 2021-01-07  A Democratic Senate provides a surge for Biden...
# 4 2021-01-08  UK’s FTSE 100 kicks off 2021 with 6% rally lif...
# 5 2021-01-09  UK’s FTSE 100 kicks off 2021 with 6% rally lif...
# 6 2021-01-10      Gazprom to restart Nord Stream 2 construction
# 7 2021-01-11  Wind power overtakes coal in Texas electricity...
# 8 2021-01-12  Climate activists choke Appalachian pipeline e...
# 9 2021-01-13  Hydrogen project aims to drive UK transition t...

# %%
df_full.to_csv('final_datasets/ft_final.csv', index=False)

# %% [markdown]
# # CNBC

# %%
df = pd.read_csv("cnbc.csv")
df
# Out:
#                                                Headline  \
# 0     Oil prices firm as geopolitical tensions raise...
# 1     Oil closes down on strong U.S. supply, losses ...
# 2     One of our lagging stocks has found its stride...
# 3     Crude oil prices steady after Ukraine hits Rus...
# 4     First-ever Capital One Landing lounge experien...
# ...                                                 ...
# 3877  OPEC+ reportedly nearing compromise on holding...
# 3878  Shares of Chinese telecom giants surge followi...
# 3879  Why the Fed’s inflation push could turn from f...
# 3880  South Korean and China’s Shenzhen stocks surge...
# 3881    Oil set for 20% drop in 2020 as lockdowns weigh
#
#                            Date
# 0      11/20/2024 8:59:26 PM ET
# 1      11/20/2024 7:36:40 AM ET
# 2     11/19/2024 12:00:39 PM ET
# 3      11/19/2024 7:51:14 AM ET
# 4      11/19/2024 7:00:01 AM ET
# ...                         ...
# 3877    1/5/2021 12:50:27 AM ET
# 3878     1/4/2021 6:40:03 PM ET
# 3879     1/4/2021 3:31:16 PM ET
# 3880     1/3/2021 6:37:58 PM ET
# 3881   12/30/2020 9:40:55 PM ET
#
# [3882 rows x 2 columns]

# %%
# Convert the Date column to datetime and only keep year, month, and day
df["Date"] = pd.to_datetime(df["Date"]).dt.date

# Define the date range
start_date = pd.to_datetime("2021-01-04").date()
end_date = pd.to_datetime("2024-10-10").date()

# Create a complete date range
all_dates = pd.date_range(start=start_date, end=end_date).date

# Filter and group data by date, concatenating headlines
df = df[(df["Date"] >= start_date) & (df["Date"] <= end_date)]
df = df.groupby("Date")["Headline"].apply(". ".join).reset_index()

# Merge with the full date range, forward-filling missing headlines
df_full = pd.DataFrame({"Date": all_dates})
df_full = df_full.merge(df, on="Date", how="left")
df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
df_full
# Out:
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/20/2024 8:59:26 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/20/2024 7:36:40 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/19/2024 12:00:39 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/19/2024 7:51:14 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/19/2024 7:00:01 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/18/2024 11:48:37 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/18/2024 8:10:15 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/18/2024 7:03:26 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/17/2024 9:58:58 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/16/2024 6:22:51 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/15/2024 10:37:01 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/15/2024 8:07:04 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/14/2024 9:17:17 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/14/2024 3:00:56 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/14/2024 8:27:23 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/13/2024 10:56:32 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/13/2024 11:28:54 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/13/2024 8:00:05 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/13/2024 5:37:06 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/13/2024 2:30:01 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/13/2024 2:07:38 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/12/2024 10:35:31 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/11/2024 9:41:03 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/10/2024 9:22:39 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/10/2024 6:50:37 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/8/2024 12:53:15 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/8/2024 12:03:56 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/6/2024 9:14:22 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/6/2024 9:35:48 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/6/2024 3:05:26 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/5/2024 9:55:36 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/5/2024 1:24:13 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/4/2024 9:41:44 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/4/2024 7:26:52 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/4/2024 4:01:26 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/3/2024 8:17:44 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/1/2024 1:58:41 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "11/1/2024 9:03:11 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/31/2024 2:05:23 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/30/2024 11:58:20 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/29/2024 9:20:18 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/29/2024 8:16:32 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/29/2024 7:34:33 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/29/2024 2:04:05 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 10:04:46 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 1:57:08 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 11:24:08 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 10:41:54 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 9:00:17 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 8:15:08 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 7:26:57 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/28/2024 1:35:28 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/27/2024 10:11:29 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/27/2024 8:05:50 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/24/2024 9:35:27 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/23/2024 8:30:31 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/23/2024 2:19:11 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/22/2024 9:00:16 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/22/2024 6:50:48 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/21/2024 8:40:36 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/21/2024 7:06:44 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/20/2024 9:33:41 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/20/2024 9:30:35 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/20/2024 9:34:34 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/18/2024 1:40:31 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/17/2024 10:55:30 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/17/2024 6:52:47 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/16/2024 10:39:48 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/16/2024 6:50:50 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/15/2024 10:22:14 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/15/2024 5:49:34 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/15/2024 1:50:55 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/15/2024 10:53:46 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/15/2024 5:47:56 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/15/2024 4:42:18 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/14/2024 10:40:12 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/14/2024 9:24:27 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/14/2024 9:24:11 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/14/2024 1:45:19 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/14/2024 11:18:23 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/14/2024 6:56:08 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/14/2024 3:20:01 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/13/2024 8:08:09 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/11/2024 7:21:35 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/10/2024 11:51:50 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/10/2024 9:52:23 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/9/2024 9:24:31 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/9/2024 8:05:52 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/9/2024 7:14:17 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/9/2024 5:45:14 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/8/2024 10:06:17 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/8/2024 1:42:28 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/8/2024 6:49:11 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/8/2024 6:17:42 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/8/2024 2:22:46 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/7/2024 8:23:12 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/7/2024 8:03:20 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/7/2024 12:16:42 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/7/2024 8:19:52 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/7/2024 7:30:38 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/7/2024 6:20:06 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/6/2024 8:48:38 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 1:40:45 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 11:01:43 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 10:44:53 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 10:02:38 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 6:30:08 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 4:18:29 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 2:07:16 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/4/2024 12:05:37 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/3/2024 11:15:55 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/3/2024 6:57:54 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/3/2024 6:50:21 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/3/2024 11:06:40 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/3/2024 7:43:27 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "10/3/2024 6:16:23 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# ...
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/14/2021 7:20:29 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/14/2021 3:52:07 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/14/2021 12:24:53 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/13/2021 6:42:34 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/13/2021 1:08:58 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/13/2021 10:05:41 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/13/2021 8:07:41 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/12/2021 9:45:51 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/12/2021 8:45:53 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/12/2021 6:44:35 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/11/2021 9:31:36 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/11/2021 6:43:14 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/11/2021 2:20:12 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/11/2021 9:45:30 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/10/2021 9:14:32 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/10/2021 6:39:09 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/7/2021 10:25:26 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/7/2021 6:42:04 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/6/2021 9:32:22 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/6/2021 7:00:50 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/6/2021 9:38:18 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/6/2021 4:18:09 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 11:25:38 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 10:49:22 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 6:48:43 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 5:37:46 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 3:30:35 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 12:04:33 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 11:05:12 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 8:51:04 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 1:08:48 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/5/2021 12:50:27 AM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/4/2021 6:40:03 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/4/2021 3:31:16 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "1/3/2021 6:37:58 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:2: FutureWarning: Parsed string "12/30/2020 9:40:55 PM ET" included an un-recognized timezone "ET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"]).dt.date
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\4108123780.py:18: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
#             Date                                           Headline
# 0     2021-01-04  Shares of Chinese telecom giants surge followi...
# 1     2021-01-05  Oil prices will remain flat until mid-2021: JB...
# 2     2021-01-06  Oil rises as supply constraints retain focus a...
# 3     2021-01-07  Oil hits highest level since February, posts n...
# 4     2021-01-08  Oil hits highest level since February, posts n...
# ...          ...                                                ...
# 1371  2024-10-06  Oil pares gains after strongest weekly rise in...
# 1372  2024-10-07  Oil edges lower after rallying to highest in o...
# 1373  2024-10-08  Oil prices steady after sliding on potential I...
# 1374  2024-10-09  Oil prices rise more than 3% on Israel-Iran co...
# 1375  2024-10-10  Oil eases though investors wary over potential...
#
# [1376 rows x 2 columns]

# %%
# Save the processed dataset to a CSV file
df_full.to_csv("final_datasets/cnbc_final.csv", index=False)

# %% [markdown]
# # OilPrice.com

# %%
df = pd.read_csv("oilprice_new.csv")
df
# Out:
#                                               Headline                   Date
# 0    Oil Prices Drop Dramatically After Israel's Li...  Oct 28, 2024 at 04:01
# 1    Saudi Oil Export Revenues Hit Three-Year Low a...  Oct 24, 2024 at 09:46
# 2    Standard Chartered: Global Oil Demand Hit An A...  Oct 23, 2024 at 14:22
# 3    Oil Prices Fluctuate Amidst China's Economic G...  Oct 18, 2024 at 03:05
# 4    Wild Oil Price Forecasts: Some Predict $350 if...  Oct 09, 2024 at 12:37
# ..                                                 ...                    ...
# 594   Oil Rally Continues Despite Slow Vaccine Rollout  Jan 08, 2021 at 11:14
# 595  The Next 5 Days Could See A Buying Spree In Oi...  Jan 07, 2021 at 09:58
# 596  OPEC+ Meeting Ends With Major Surprise Cut Fro...  Jan 05, 2021 at 12:46
# 597  Oil Rallies As Russia Agrees With OPEC+ Not To...  Jan 05, 2021 at 09:16
# 598  Oil Rises As Market Awaits OPEC+ Production De...  Jan 04, 2021 at 08:53
#
# [599 rows x 2 columns]

# %%
# Convert the Date column to datetime and format it to only include month, day, and year
df["Date"] = pd.to_datetime(df["Date"], format="%b %d, %Y at %H:%M").dt.date

# Define the date range
start_date = pd.to_datetime("2021-01-04").date()
end_date = pd.to_datetime("2024-10-10").date()

# Create a complete date range
all_dates = pd.date_range(start=start_date, end=end_date).date

# Filter data to only include rows within the specified date range
df = df[(df["Date"] >= start_date) & (df["Date"] <= end_date)]

# Group data by date, concatenating headlines with ". "
df_grouped = df.groupby("Date")["Headline"].apply(". ".join).reset_index()

# Create a DataFrame with the full date range
df_full = pd.DataFrame({"Date": all_dates})

# Merge with the grouped data, ensuring all dates are present
df_full = df_full.merge(df_grouped, on="Date", how="left")

# Forward fill missing headlines
df_full["Headline"] = df_full["Headline"].fillna(method="ffill")

# Show the final DataFrame
df_full
# Out:
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\158636318.py:24: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
#             Date                                           Headline
# 0     2021-01-04  Oil Rises As Market Awaits OPEC+ Production De...
# 1     2021-01-05  OPEC+ Meeting Ends With Major Surprise Cut Fro...
# 2     2021-01-06  OPEC+ Meeting Ends With Major Surprise Cut Fro...
# 3     2021-01-07  The Next 5 Days Could See A Buying Spree In Oi...
# 4     2021-01-08   Oil Rally Continues Despite Slow Vaccine Rollout
# ...          ...                                                ...
# 1371  2024-10-06  Oil Explodes 4% Amid Talk of Israel Attacking ...
# 1372  2024-10-07     Historic Short Squeeze Sends Oil Prices Higher
# 1373  2024-10-08     Historic Short Squeeze Sends Oil Prices Higher
# 1374  2024-10-09  Wild Oil Price Forecasts: Some Predict $350 if...
# 1375  2024-10-10  Wild Oil Price Forecasts: Some Predict $350 if...
#
# [1376 rows x 2 columns]

# %%
# Save the processed dataset to a CSV file
df_full.to_csv("final_datasets/oilprice_final.csv", index=False)

# %% [markdown]
# # MEES

# %%
df = pd.read_csv("mees_opec_headlines.csv")
df
# Out:
#                                               Headline          Date
# 0    Oman: New Gas Output For Q3 As Oil Constrained...  Nov 15, 2024
# 1    India Crude Imports: Russia Dominant As Saudi ...  Nov 15, 2024
# 2    Opec Extends Cuts As Trump Return Complicates ...   Nov 8, 2024
# 3                      China Crude Imports: Down Again   Nov 8, 2024
# 4    Brazil Oil Output: Q3 Down But More Growth To ...   Nov 8, 2024
# ..                                                 ...           ...
# 760                     Opec Aims For More Stable 2021   Jan 4, 2021
# 761  US Mideast Crude Imports Fall To New 35-Year Lows   Jan 4, 2021
# 762   Will A Resurgent Iran Flood Oil Markets In 2021?  Dec 18, 2020
# 763    DME Oman: Assessing A Key Middle East Benchmark  Dec 18, 2020
# 764  Opec, IEA Counter Market Euphoria With Demand ...  Dec 18, 2020
#
# [765 rows x 2 columns]

# %%
# Convert the Date column to datetime and format it to only include month, day, and year
df["Date"] = pd.to_datetime(df["Date"], format="%b %d, %Y").dt.date

# Define the date range
start_date = pd.to_datetime("2021-01-04").date()
end_date = pd.to_datetime("2024-10-10").date()

# Create a complete date range
all_dates = pd.date_range(start=start_date, end=end_date).date

# Filter data to only include rows within the specified date range
df = df[(df["Date"] >= start_date) & (df["Date"] <= end_date)]

# Group data by date, concatenating headlines with ". "
df_grouped = df.groupby("Date")["Headline"].apply(". ".join).reset_index()

# Create a DataFrame with the full date range
df_full = pd.DataFrame({"Date": all_dates})

# Merge with the grouped data, ensuring all dates are present
df_full = df_full.merge(df_grouped, on="Date", how="left")

# Forward fill missing headlines
df_full["Headline"] = df_full["Headline"].fillna(method="ffill")

# Show the final DataFrame
df_full
# Out:
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\2528989937.py:24: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
#             Date                                           Headline
# 0     2021-01-04  Opec Aims For More Stable 2021. US Mideast Cru...
# 1     2021-01-05  Opec Aims For More Stable 2021. US Mideast Cru...
# 2     2021-01-06  Opec Aims For More Stable 2021. US Mideast Cru...
# 3     2021-01-07  Opec Aims For More Stable 2021. US Mideast Cru...
# 4     2021-01-08  Algeria’s Gas Exports Slump To 25-Year Low For...
# ...          ...                                                ...
# 1371  2024-10-06       Compliance In Spotlight At Opec JMMC Meeting
# 1372  2024-10-07       Compliance In Spotlight At Opec JMMC Meeting
# 1373  2024-10-08       Compliance In Spotlight At Opec JMMC Meeting
# 1374  2024-10-09       Compliance In Spotlight At Opec JMMC Meeting
# 1375  2024-10-10       Compliance In Spotlight At Opec JMMC Meeting
#
# [1376 rows x 2 columns]

# %%
# Save the processed dataset to a CSV file
df_full.to_csv("final_datasets/mees_final.csv", index=False)

# %% [markdown]
# # Arab News

# %%
df = pd.read_csv("arabnews_articles.csv")
df
# Out:
#                                               Headline  \
# 0    Oil Updates – market sees losses on tight supp...
# 1    Saudi Aramco slashes December oil prices for A...
# 2    Pakistan party protests increase in petroleum ...
# 3    Oil Updates – prices dip as geopolitical risks...
# 4    Oil Updates – crude edges up from two-week low...
# ..                                                 ...
# 221  Quick action by OPEC+ stabilized oil markets d...
# 222  Brent crude to hit $75 as demand recovery outs...
# 223             Weekly energy recap: February 19, 2021
# 224  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 225  WEEKLY ENERGY RECAP: Oil prices on an upward m...
#
#                                      Date
# 0    Wednesday 13, November 2024 10.15 am
# 1      Wednesday 6, November 2024 2.44 pm
# 2        Friday 1, November 2024 11.41 am
# 3       Tuesday 22, October 2024 10.23 am
# 4       Thursday 17, October 2024 9.09 am
# ..                                    ...
# 221         Monday 1, March 2021 10.40 am
# 222      Monday 22, February 2021 9.30 pm
# 223    Saturday 20, February 2021 5.23 pm
# 224    Saturday 16, January 2021 10.43 pm
# 225     Saturday 4, January 2021 11.17 pm
#
# [226 rows x 2 columns]

# %%
# Convert the Date column to datetime and format it to only include month, day, and year
df["Date"] = pd.to_datetime(df["Date"], format="%A %d, %B %Y %I.%M %p").dt.date

# Define the date range
start_date = pd.to_datetime("2021-01-04").date()
end_date = pd.to_datetime("2024-10-10").date()

# Create a complete date range
all_dates = pd.date_range(start=start_date, end=end_date).date

# Filter data to only include rows within the specified date range
df = df[(df["Date"] >= start_date) & (df["Date"] <= end_date)]

# Group data by date, concatenating headlines with ". "
df_grouped = df.groupby("Date")["Headline"].apply(". ".join).reset_index()

# Create a DataFrame with the full date range
df_full = pd.DataFrame({"Date": all_dates})

# Merge with the grouped data, ensuring all dates are present
df_full = df_full.merge(df_grouped, on="Date", how="left")

# Forward fill missing headlines
df_full["Headline"] = df_full["Headline"].fillna(method="ffill")

# Show the final DataFrame
df_full.head(20)
# Out:
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\2343877716.py:24: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
#           Date                                           Headline
# 0   2021-01-04  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 1   2021-01-05  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 2   2021-01-06  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 3   2021-01-07  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 4   2021-01-08  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 5   2021-01-09  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 6   2021-01-10  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 7   2021-01-11  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 8   2021-01-12  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 9   2021-01-13  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 10  2021-01-14  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 11  2021-01-15  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 12  2021-01-16  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 13  2021-01-17  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 14  2021-01-18  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 15  2021-01-19  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 16  2021-01-20  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 17  2021-01-21  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 18  2021-01-22  WEEKLY ENERGY RECAP: A mixed week for oil with...
# 19  2021-01-23  WEEKLY ENERGY RECAP: A mixed week for oil with...

# %%
# Save the processed dataset to a CSV file
df_full.to_csv("final_datasets/arabnews_final.csv", index=False)

# %% [markdown]
# # Energy Intelligence

# %%
import pandas as pd

# List of CSV files to concatenate
csv_files = [
    "energy_intel_results_2021.csv",
    "energy_intel_results_2022.csv",
    "energy_intel_results.csv",
]

# List to hold DataFrames
dataframes = []

# Read each CSV file into a DataFrame and append to the list
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Concatenate all DataFrames
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df
# Out:
#                                                Headline               Date
# 0      US Oil Demand Falls Well Short of Forecasts: EIA  Thu, Dec 30, 2021
# 1                    Shell Lifts Forcados Force Majeure  Thu, Dec 30, 2021
# 2          Brent Takes Aim at $80 Heading Into New Year  Thu, Dec 30, 2021
# 3      Libya Strives to Keep Up Exports Despite Outages  Thu, Dec 30, 2021
# 4      Russia's Seaborne Exports Set to Rise in January  Thu, Dec 30, 2021
# ...                                                 ...                ...
# 7518                  Chevron to Export Venezuela Cargo   Tue, Jan 3, 2023
# 7519      Oil, Diesel Futures Start New Year in Decline   Tue, Jan 3, 2023
# 7520  Russian Oil Output Flat in December, Exports Sink   Tue, Jan 3, 2023
# 7521               Iraq's Oil Revenues Hit 12-Month Low   Tue, Jan 3, 2023
# 7522      China Awards First 2023 Product Export Quotas   Tue, Jan 3, 2023
#
# [7523 rows x 2 columns]

# %%
# Filter out rows with "No date" or "No headline"
combined_df = combined_df[(combined_df['Date'] != "No date") & (combined_df['Headline'] != "No headline")]

# Convert the 'Date' column to datetime format
combined_df['Date'] = pd.to_datetime(combined_df['Date'], format='%a, %b %d, %Y')  # Adjusting format to match the dataset

# Sort the DataFrame by Date to ensure chronological order
combined_df = combined_df.sort_values('Date')

# Combine headlines for duplicate dates
df_grouped = combined_df.groupby('Date', as_index=False).agg({'Headline': '. '.join})

# Reset the index for the grouped DataFrame
df_grouped.reset_index(drop=True, inplace=True)
df_grouped
# Out:
#           Date                                           Headline
# 0   2021-01-04          Schlumberger Optimistic for 2021 Recovery
# 1   2021-01-28      UAE Sour Gas Bids Deadline Pushed to February
# 2   2021-02-04        Chevron Makes $1.1B Bid for Noble Midstream
# 3   2021-02-16  Continental Expands Into Powder River Despite ...
# 4   2021-02-17  Shell Sells Canada Duvernay Shale Assets. Shel...
# ..         ...                                                ...
# 852 2024-10-28  Oil Prices Slide as Traders Reassess Risk Prem...
# 853 2024-10-29  Indian Refiners Eye Cuts to Saudi Term Volumes...
# 854 2024-10-30  Oil Prices Rebound as US Inventories Slide Low...
# 855 2024-10-31  US Product Exports Climb to New All-Time High:...
# 856 2024-11-01  Oil Posts Small Gain, But Down for Week. US Ri...
#
# [857 rows x 2 columns]

# %%
start_date = pd.Timestamp('2021-01-04')
end_date = pd.Timestamp('2024-10-10')

final_df = df_grouped[(df_grouped['Date'] >= start_date) & (df_grouped['Date'] <= end_date)]
final_df
# Out:
#           Date                                           Headline
# 0   2021-01-04          Schlumberger Optimistic for 2021 Recovery
# 1   2021-01-28      UAE Sour Gas Bids Deadline Pushed to February
# 2   2021-02-04        Chevron Makes $1.1B Bid for Noble Midstream
# 3   2021-02-16  Continental Expands Into Powder River Despite ...
# 4   2021-02-17  Shell Sells Canada Duvernay Shale Assets. Shel...
# ..         ...                                                ...
# 835 2024-10-04  US Rig Count Enters Fourth Quarter in Decline....
# 836 2024-10-07  Aramco Hikes November Prices for Asia Crude Ex...
# 837 2024-10-08  Demand Concerns Outweigh Mideast Turmoil in EI...
# 838 2024-10-09  Oil Prices Dip Amid Demand, Risk Crosscurrents...
# 839 2024-10-10  EIA Details Tankers, Ports Involved in Iran Oi...
#
# [840 rows x 2 columns]

# %%
full_date_range = pd.date_range(start=start_date, end=end_date)

# Create a DataFrame with the full date range
df_full = pd.DataFrame({"Date": full_date_range})

# Merge with the grouped DataFrame
df_full = df_full.merge(final_df, on="Date", how="left")

# Forward fill missing headlines
df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
df_full
# Out:
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\3513607462.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_full["Headline"] = df_full["Headline"].fillna(method="ffill")
#            Date                                           Headline
# 0    2021-01-04          Schlumberger Optimistic for 2021 Recovery
# 1    2021-01-05          Schlumberger Optimistic for 2021 Recovery
# 2    2021-01-06          Schlumberger Optimistic for 2021 Recovery
# 3    2021-01-07          Schlumberger Optimistic for 2021 Recovery
# 4    2021-01-08          Schlumberger Optimistic for 2021 Recovery
# ...         ...                                                ...
# 1371 2024-10-06  US Rig Count Enters Fourth Quarter in Decline....
# 1372 2024-10-07  Aramco Hikes November Prices for Asia Crude Ex...
# 1373 2024-10-08  Demand Concerns Outweigh Mideast Turmoil in EI...
# 1374 2024-10-09  Oil Prices Dip Amid Demand, Risk Crosscurrents...
# 1375 2024-10-10  EIA Details Tankers, Ports Involved in Iran Oi...
#
# [1376 rows x 2 columns]

# %%
df_full.to_csv('final_datasets/ei_final.csv', index=False)

# %% [markdown]
# # OPEC

# %%
df = pd.read_csv("opec.csv")
df
# Out:
#            date                                               text
# 0    2021-12-14  Communique of the African Petroleum Producers’...
# 1    2021-12-10  The Declaration of Cooperation of OPEC and non...
# 2    2021-12-02  23rd OPEC and non-OPEC Ministerial Meeting\nNo...
# 3    2021-12-01  Opening address to the 182nd Meeting of the OP...
# 4    2021-11-30  OPEC marks the 5th anniversary of the landmark...
# ..          ...                                                ...
# 127  2024-03-19  The Seventh High-Level Meeting of the OPEC-Chi...
# 128  2024-03-03  Several OPEC+ countries announce extension of ...
# 129  2024-02-19  OPEC and Africa exchange views on array of key...
# 130  2024-02-01  52nd Meeting of the Joint Ministerial Monitori...
# 131  2024-01-03  OPEC and non-OPEC oil-producing countries re-a...
#
# [132 rows x 2 columns]

# %%
# Use the "date" column as the Date column
df["Date"] = pd.to_datetime(df["date"])

# Define the date range
start_date = pd.to_datetime("2021-01-04")
end_date = pd.to_datetime("2024-10-10")

# Create a complete date range
all_dates = pd.date_range(start=start_date, end=end_date)

# Filter data to only include rows within the specified date range
df = df[(df["Date"] >= start_date) & (df["Date"] <= end_date)]

# Group data by date, concatenating text with ". "
df_grouped = df.groupby("Date")["text"].apply(". ".join).reset_index()

# Create a DataFrame with the full date range
df_full = pd.DataFrame({"Date": all_dates})

# Merge with the grouped data, ensuring all dates are present
df_full = df_full.merge(df_grouped, on="Date", how="left")

# Forward fill missing text
df_full["text"] = df_full["text"].fillna(method="ffill")

# Show the final DataFrame
print(df_full.head(20))

# Save the final DataFrame
df_full.to_csv(r"final_datasets\opec_full.csv", index=False)
# Out:
#          Date                                               text
# 0  2021-01-04  The 13th OPEC and non-OPEC Ministerial Meeting...
# 1  2021-01-05  13th OPEC and non-OPEC Ministerial Meeting con...
# 2  2021-01-06  13th OPEC and non-OPEC Ministerial Meeting con...
# 3  2021-01-07  13th OPEC and non-OPEC Ministerial Meeting con...
# 4  2021-01-08  13th OPEC and non-OPEC Ministerial Meeting con...
# 5  2021-01-09  13th OPEC and non-OPEC Ministerial Meeting con...
# 6  2021-01-10  13th OPEC and non-OPEC Ministerial Meeting con...
# 7  2021-01-11  13th OPEC and non-OPEC Ministerial Meeting con...
# 8  2021-01-12  13th OPEC and non-OPEC Ministerial Meeting con...
# 9  2021-01-13  13th OPEC and non-OPEC Ministerial Meeting con...
# 10 2021-01-14  13th OPEC and non-OPEC Ministerial Meeting con...
# 11 2021-01-15  13th OPEC and non-OPEC Ministerial Meeting con...
# 12 2021-01-16  13th OPEC and non-OPEC Ministerial Meeting con...
# 13 2021-01-17  13th OPEC and non-OPEC Ministerial Meeting con...
# 14 2021-01-18  13th OPEC and non-OPEC Ministerial Meeting con...
# 15 2021-01-19  13th OPEC and non-OPEC Ministerial Meeting con...
# 16 2021-01-20  13th OPEC and non-OPEC Ministerial Meeting con...
# 17 2021-01-21  13th OPEC and non-OPEC Ministerial Meeting con...
# 18 2021-01-22  13th OPEC and non-OPEC Ministerial Meeting con...
# 19 2021-01-23  13th OPEC and non-OPEC Ministerial Meeting con...
# C:\Users\Richie Zhang\AppData\Local\Temp\ipykernel_47924\290902373.py:24: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_full["text"] = df_full["text"].fillna(method="ffill")

# %%
df_full
# Out:
#            Date                                               text
# 0    2021-01-04  The 13th OPEC and non-OPEC Ministerial Meeting...
# 1    2021-01-05  13th OPEC and non-OPEC Ministerial Meeting con...
# 2    2021-01-06  13th OPEC and non-OPEC Ministerial Meeting con...
# 3    2021-01-07  13th OPEC and non-OPEC Ministerial Meeting con...
# 4    2021-01-08  13th OPEC and non-OPEC Ministerial Meeting con...
# ...         ...                                                ...
# 1371 2024-10-06  56th Meeting of the Joint Ministerial Monitori...
# 1372 2024-10-07  56th Meeting of the Joint Ministerial Monitori...
# 1373 2024-10-08  56th Meeting of the Joint Ministerial Monitori...
# 1374 2024-10-09  56th Meeting of the Joint Ministerial Monitori...
# 1375 2024-10-10  Fifth High-Level Meeting of the OPEC-GECF Ener...
#
# [1376 rows x 2 columns]

# %% [markdown]
# # COMBINE EVERYTHING

# %%
import glob

# Define the path to the directory containing the CSV files
file_path = "final_datasets/*.csv"

# Load all the CSV files
csv_files = glob.glob(file_path)

# Create an empty DataFrame to hold combined data
combined_data = pd.DataFrame()

# Iterate through each CSV file
for file in csv_files:
    df = pd.read_csv(file)
    # Ensure the 'Date' column is parsed and consistent across datasets
    df['Date'] = pd.to_datetime(df['Date'])
    source_name = file.split("\\")[-1].replace("_final.csv", "")  # Adjusted for Windows file path
    df.rename(columns={"Headline": source_name}, inplace=True)  # Rename the 'Headline' column to the source name
    if combined_data.empty:
        combined_data = df
    else:
        combined_data = pd.merge(combined_data, df, on="Date", how="outer")  # Merge on 'Date'

# Sort by date and reset the index
combined_data = combined_data.sort_values("Date").reset_index(drop=True)

# Rename the 'text' column to 'opec'
combined_data = combined_data.rename(columns={"text": "opec"})

# Save the combined DataFrame
combined_data.to_csv("combined_final_dataset.csv", index=False)
combined_data
# Out:
#            Date                                           arabnews  \
# 0    2021-01-04  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 1    2021-01-05  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 2    2021-01-06  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 3    2021-01-07  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# 4    2021-01-08  WEEKLY ENERGY RECAP: Oil prices on an upward m...
# ...         ...                                                ...
# 1371 2024-10-06  Oman credit rating rises to ‘BBB-’ from ‘BB+’:...
# 1372 2024-10-07  Oman credit rating rises to ‘BBB-’ from ‘BB+’:...
# 1373 2024-10-08  Pakistan’s stock market surpasses historic 85,...
# 1374 2024-10-09  Pakistan’s stock market surpasses historic 85,...
# 1375 2024-10-10  Pakistan’s stock market surpasses historic 85,...
#
#                                                    cnbc  \
# 0     Shares of Chinese telecom giants surge followi...
# 1     Oil prices will remain flat until mid-2021: JB...
# 2     Oil rises as supply constraints retain focus a...
# 3     Oil hits highest level since February, posts n...
# 4     Oil hits highest level since February, posts n...
# ...                                                 ...
# 1371  Oil pares gains after strongest weekly rise in...
# 1372  Oil edges lower after rallying to highest in o...
# 1373  Oil prices steady after sliding on potential I...
# 1374  Oil prices rise more than 3% on Israel-Iran co...
# 1375  Oil eases though investors wary over potential...
#
#                                                      ei  \
# 0             Schlumberger Optimistic for 2021 Recovery
# 1             Schlumberger Optimistic for 2021 Recovery
# 2             Schlumberger Optimistic for 2021 Recovery
# 3             Schlumberger Optimistic for 2021 Recovery
# 4             Schlumberger Optimistic for 2021 Recovery
# ...                                                 ...
# 1371  US Rig Count Enters Fourth Quarter in Decline....
# 1372  Aramco Hikes November Prices for Asia Crude Ex...
# 1373  Demand Concerns Outweigh Mideast Turmoil in EI...
# 1374  Oil Prices Dip Amid Demand, Risk Crosscurrents...
# 1375  EIA Details Tankers, Ports Involved in Iran Oi...
#
#                                                      ft  \
# 0     Saudi Arabia warns oil producers over fragile ...
# 1     Saudis pledge to cut oil output despite Russia...
# 2     Oil auction in Arctic wildlife refuge draws sc...
# 3     A Democratic Senate provides a surge for Biden...
# 4     UK’s FTSE 100 kicks off 2021 with 6% rally lif...
# ...                                                 ...
# 1371  TotalEnergies considers foray into copper trad...
# 1372  Oil surges above $80 as conflict and storm spa...
# 1373  Chevron in talks to sell Texas gas assets to T...
# 1374  Who and what is driving oil price volatility. ...
# 1375  Surging US power demand set to exceed supply, ...
#
#                                                    mees  \
# 0     Opec Aims For More Stable 2021. US Mideast Cru...
# 1     Opec Aims For More Stable 2021. US Mideast Cru...
# 2     Opec Aims For More Stable 2021. US Mideast Cru...
# 3     Opec Aims For More Stable 2021. US Mideast Cru...
# 4     Algeria’s Gas Exports Slump To 25-Year Low For...
# ...                                                 ...
# 1371       Compliance In Spotlight At Opec JMMC Meeting
# 1372       Compliance In Spotlight At Opec JMMC Meeting
# 1373       Compliance In Spotlight At Opec JMMC Meeting
# 1374       Compliance In Spotlight At Opec JMMC Meeting
# 1375       Compliance In Spotlight At Opec JMMC Meeting
#
#                                                oilprice  \
# 0     Oil Rises As Market Awaits OPEC+ Production De...
# 1     OPEC+ Meeting Ends With Major Surprise Cut Fro...
# 2     OPEC+ Meeting Ends With Major Surprise Cut Fro...
# 3     The Next 5 Days Could See A Buying Spree In Oi...
# 4      Oil Rally Continues Despite Slow Vaccine Rollout
# ...                                                 ...
# 1371  Oil Explodes 4% Amid Talk of Israel Attacking ...
# 1372     Historic Short Squeeze Sends Oil Prices Higher
# 1373     Historic Short Squeeze Sends Oil Prices Higher
# 1374  Wild Oil Price Forecasts: Some Predict $350 if...
# 1375  Wild Oil Price Forecasts: Some Predict $350 if...
#
#                                                    opec
# 0     The 13th OPEC and non-OPEC Ministerial Meeting...
# 1     13th OPEC and non-OPEC Ministerial Meeting con...
# 2     13th OPEC and non-OPEC Ministerial Meeting con...
# 3     13th OPEC and non-OPEC Ministerial Meeting con...
# 4     13th OPEC and non-OPEC Ministerial Meeting con...
# ...                                                 ...
# 1371  56th Meeting of the Joint Ministerial Monitori...
# 1372  56th Meeting of the Joint Ministerial Monitori...
# 1373  56th Meeting of the Joint Ministerial Monitori...
# 1374  56th Meeting of the Joint Ministerial Monitori...
# 1375  Fifth High-Level Meeting of the OPEC-GECF Ener...
#
# [1376 rows x 8 columns]
